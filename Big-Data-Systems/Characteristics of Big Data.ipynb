# %% [markdown]
# ## Lesson overview: Characteristics and Business Value of Big Data

# %% [markdown]
# ![image.png](attachment:87d9766d-4f4b-40be-b26e-455a69655767.png)

# %% [markdown]
# https://www.youtube.com/watch?v=_ySp9u_RZ58

# %% [markdown]
# ![image.png](attachment:2592b7c4-c341-4935-a74a-3f2681edebd6.png)

# %% [markdown]
# ![image.png](attachment:a68441d6-bc8d-4431-9de3-d68cf2543ed1.png)

# %% [markdown]
# ## Why Big Data Matters

# %% [markdown]
# https://www.youtube.com/watch?v=KXOyOQxUCUo

# %% [markdown]
# ![image.png](attachment:2e1c070d-eace-4b51-bf40-f691fce121bc.png)

# %% [markdown]
# ![image.png](attachment:3f6eaefc-3940-4b2f-913a-04a8abf3ff8e.png)

# %% [markdown]
# ## How Companies are Using Big Data?

# %% [markdown]
# https://www.youtube.com/watch?v=ZO47noueE5c

# %% [markdown]
# From small to large, thousands of companies in a variety of industries are using Big Data today to improve their products, drive better customer engagement, or building new services to generate new revenue streams. These industries include Insurance, Banking, Healthcare, Government, Media & Entertainment, and IoT

# %% [markdown]
# https://www.youtube.com/watch?v=YXXBSHT0Gd8

# %% [markdown]
# Here we reviewed several companies using Big Data to solve their business needs and data scaling demands. This included major Search Engines, Ride Sharing, Video Sharing, and Social media companies.

# %% [markdown]
# ## 4V's of Big Data

# %% [markdown]
# https://www.youtube.com/watch?v=IUt3iYarnJs

# %% [markdown]
# ![image.png](attachment:3ce98c01-66bb-41c3-87e5-8a5eba2559fa.png)

# %% [markdown]
# While there is crossover between these characteristics of the data, the following graphic can give you a sense of how they differ along with some industry examples

# %% [markdown]
# ![image.png](attachment:de9fbf42-145c-4f19-8cdd-ba623d090386.png)

# %% [markdown]
# ## Quiz: 4V's of Big Data

# %% [markdown]
# ![image.png](attachment:febcb950-5115-44d7-800d-0f3efd92fcdd.png)

# %% [markdown]
# ![image.png](attachment:1578adf5-8ac2-4a11-bdf9-5d1406ecdb0d.png)
