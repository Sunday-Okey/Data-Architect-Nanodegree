# %% [markdown]
# ## Meet Your Instructor

# %% [markdown]
# https://www.youtube.com/watch?v=fCw6NfSJZEQ

# %% [markdown]
# ![image.png](attachment:4b7ce7eb-ae74-4953-be6e-c5638d9ef9ea.png)

# %% [markdown]
# ## Course Overview

# %% [markdown]
# ### Course Outline

# %% [markdown]
# ![image.png](attachment:1a0e7966-d524-40d1-86f8-bc640203a3c4.png)

# %% [markdown]
# https://www.youtube.com/watch?v=va1I1cWPG-Y

# %% [markdown]
# ![image.png](attachment:7811efb8-5954-4e55-b416-0050548b4465.png)

# %% [markdown]
# ![image.png](attachment:ec5c6b73-a46f-4118-a806-6e166acdeb06.png)

# %% [markdown]
# ## Lesson Outline

# %% [markdown]
# https://www.youtube.com/watch?v=ciJozaIFmx8

# %% [markdown]
# ![image.png](attachment:f1ee4736-b9ea-4152-97ef-957eb7342b39.png)

# %% [markdown]
# ![image.png](attachment:6b1fbf23-b375-4d74-b2b6-0b25a9cb1e36.png)

# %% [markdown]
# ## Introduction to Big Data Systems

# %% [markdown]
# https://www.youtube.com/watch?v=14XMk9ogYRo

# %% [markdown]
# ![image.png](attachment:d7d27219-4110-4a99-8dca-44a6c0d3ec5a.png)

# %% [markdown]
# ![image.png](attachment:26c02a90-7e81-4450-ad4b-bccdaf63dc99.png)

# %% [markdown]
# How do you know if your data is considered Big Data? We will dive deep into this in the next lesson, the graphic below describes characteristics of data, any one of which is enough to mean you are dealing with Big Data.

# %% [markdown]
# ![image.png](attachment:5cbfc1af-17d6-4b79-beb8-c91a1c16e7ae.png)

# %% [markdown]
# ## Why Big Data Matters

# %% [markdown]
# https://www.youtube.com/watch?v=XmfoLy5czAs

# %% [markdown]
# ![image.png](attachment:12c1d979-53ae-4a10-95e4-3f010c1c27a9.png)

# %% [markdown]
# ![image.png](attachment:1cad5151-0754-4efd-a223-32a5b408a152.png)

# %% [markdown]
# Big Data is at the center of an organizations ability to reduce cost, innovate, and make strategic decisions

# %% [markdown]
# ![image.png](attachment:28ded798-6fa2-4dec-a849-4daafc3ce4b2.png)

# %% [markdown]
# ## Business Stakeholders

# %% [markdown]
# https://www.youtube.com/watch?v=IVCkIZAxRNI

# %% [markdown]
# ![image.png](attachment:a6c047b6-4311-4213-ac61-fd5237b90298.png)

# %% [markdown]
# ![image.png](attachment:0c39934b-45ea-4da0-971f-6bddc7e9e5b6.png)

# %% [markdown]
# ## When to use or not use Big Data

# %% [markdown]
# https://www.youtube.com/watch?v=mkZ5Rdjnmy4

# %% [markdown]
# ![image.png](attachment:133c5bc8-1323-4ccc-9ae9-94c4e40ca6dd.png)

# %% [markdown]
# ![image.png](attachment:ab8b9d6d-12aa-4def-8001-e7f775ceff30.png)

# %% [markdown]
# ## History of Big Data

# %% [markdown]
# ### History and Evolution of Big Data

# %% [markdown]
# https://www.youtube.com/watch?v=d9iPilXN4Ns

# %% [markdown]
# After the initial research paper for Google in 2003, the first open-source version of "Google File System" called "Hadoop" was rolled out by Yahoo in 2006 and then Apache Spark in 2013, we have seen these 2 products lead the way to transform this industry.
#
# As of the time of making this course, both products are in their 3.0 release.

# %% [markdown]
# ![image.png](attachment:06afb0ed-ba6b-4d8c-bae1-70412b8df517.png)

# %% [markdown]
# ## Tools, Environment & Dependencies

# %% [markdown]
# https://www.youtube.com/watch?v=uvsKoD74pHM

# %% [markdown]
# ![image.png](attachment:5feeab77-83ff-4041-a4d3-262a12ce1db7.png)

# %% [markdown]
# ## Project: Design Enterprise Data Lake system for Medical Data Processing Company

# %% [markdown]
# https://www.youtube.com/watch?v=ZNmDX-FgvQE

# %% [markdown]
# In your final product, you will be assuming the role of Big Data Architect as you research a real business scenario where a medical processing company with over 8000 clients is seeing huge growth in data over the last few years. You are charged with researching, proposing, justifying, and presenting your actual Big Data Lake solution to the executive team. It will require you o understand how all the concepts, as well as the tools to implement them, come together to solve a common and realistic business problem.

# %% [markdown]
# ## Lesson Review

# %% [markdown]
# https://www.youtube.com/watch?v=1tr-Ew_I8gI

# %% [markdown]
# ![image.png](attachment:065ca531-d63d-4c8d-9ecb-17c1dedb1564.png)

# %% [markdown]
# ## Let's Go!

# %% [markdown]
# https://www.youtube.com/watch?v=7unpL4yAuFM

# %% [markdown]
# To get the most out of this course, students will want to dive into the hands-on components. This includes quizzes and exercises. This, along with your video lessons will help you, not only fully understand, but also be skilled at, this amazing topic called BIG DATA
#
# Let's begin!

# %% [markdown]
# ## Glossary

# %% [markdown]
# ![image.png](attachment:05532ca5-0998-4a43-beb8-af75c57a2fce.png)

# %% [markdown]
# ![image.png](attachment:e4b8fb96-f446-4ede-bdeb-2e489afb3bcb.png)

# %% [markdown]
# https://www.sas.com/en_us/insights/big-data/what-is-big-data.html

# %% [markdown]
# https://www.precisely.com/blog/big-data/quality-data-big-data-worth#:~:text=The%20big%20data%20market%20is,they%20were%20deriving%20from%20it

# %% [markdown]
# https://www.i-scoop.eu/big-data-action-value-context/
